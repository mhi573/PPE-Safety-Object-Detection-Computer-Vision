# %% [markdown]
# # MSDS498: AI Capstone project
# # Utilizing Pre-trained Models for Object Detection: PPE Safety Computer Vision Project Proof of Concept
#
# <p><b>Data source: https://data.mendeley.com/datasets/zkzghjvpn2/2</p></b>

# %% [markdown]
# ## Data Pre-Processing

# %% [markdown]
# ### Setup Initial Environment

# %%
##########################################################
#
#   Set Screen Attributes
#
##########################################################

from IPython.core.interactiveshell import InteractiveShell
from IPython.display import display, HTML
import pandas as pd

InteractiveShell.ast_node_interactivity = "all"

# set cell width
display(HTML("<style>.container { width:100% !important; }</style>"))

# set cell output window height
display(HTML("<style>div.output_scroll { height: 160em;} </style>"))

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
# Out:
# <style>.container { width:100% !important; }</style>
# <style>div.output_scroll { height: 160em;} </style>

# %%
#pip install pyyaml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

os.getcwd()

#set working Directory
#os.chdir('')
# Out:
# 'C:\\Users\\mhurt\\Documents\\MSDS498'

# %% [markdown]
# ### Labels

# %%
import yaml

subfolder = 'NewPPE25-3212'
filename = 'data.yaml'
filepath = os.path.join(subfolder, filename)


# Load the YAML file
with open(filepath, 'r') as file:
    data = yaml.safe_load(file)

# View the data
print(data)
# Out:
# {'path': 'C:/Users/0/Desktop/yolov111124/NewPPE25-3212', 'train': 'C:/Users/0/Desktop/yolov111124/NewPPE25-3212/train/images', 'val': 'C:/Users/0/Desktop/yolov111124/NewPPE25-3212/valid/images', 'test': None, 'nc': 4, 'names': {0: 'Helmet', 1: 'NoHelmet', 2: 'NoVest', 3: 'Vest'}}

# %% [markdown]
# | Label ID | Label Name      | Description              |
# |----------|------------------|--------------------------|
# | 0        | Helmet | Yes, wearing a safety helmet             |
# | 1        | NoHelmet | No, not wearing a safety helmet             |
# | 2        | NoVest | No, not wearing a safety vest             |
# | 3        | Vest | Yes, wearing a safety vest            |

# %%
#pip install cv2

# %%
#pip install matplotlib

# %%
import cv2
import matplotlib.pyplot as plt

# Path to the image
image_path = 'C:/Users/mhurt/Documents/MSDS498/NewPPE25-3212/train/images/000004_jpg.rf.93e8f031df4e00fc4ce3a66869747cf4.jpg' 

# Read image using OpenCV (loads in BGR format)
image = cv2.imread(image_path)

# Convert BGR to RGB for correct color display in matplotlib
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(image_rgb)
plt.title('Displayed Image:')
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 1.0, 'Displayed Image')
# (-0.5, 639.5, 639.5, -0.5)

# %%
with open('C:/Users/mhurt/Documents/MSDS498/NewPPE25-3212/train/labels/000004_jpg.rf.93e8f031df4e00fc4ce3a66869747cf4.txt','r') as file:
    head = file.read()
    print(head)
# Out:
# 1 0.7796875 0.309375 0.12578125 0.22734375
# 1 0.68359375 0.32578125 0.075 0.1515625
# 1 0.625 0.3421875 0.046875 0.11484375
# 1 0.9265625 0.3890625 0.08828125 0.175
# 1 0.58671875 0.36640625 0.05 0.0890625
# 1 0.86875 0.35390625 0.08046875 0.15078125
